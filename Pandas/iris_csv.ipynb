# %% [markdown]
# <a href="https://colab.research.google.com/github/navi004/cse3041/blob/main/Pandas/iris_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/sample_data/iris.csv')
df
# Out:
#       Id  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width         species
# 0      1           5.1          3.5           1.4          0.2     Iris-setosa
# 1      2           4.9          3.0           1.4          0.2     Iris-setosa
# 2      3           4.7          3.2           1.3          0.2     Iris-setosa
# 3      4           4.6          3.1           1.5          0.2     Iris-setosa
# 4      5           5.0          3.6           1.4          0.2     Iris-setosa
# ..   ...           ...          ...           ...          ...             ...
# 145  146           6.7          3.0           5.2          2.3  Iris-virginica
# 146  147           6.3          2.5           5.0          1.9  Iris-virginica
# 147  148           6.5          3.0           5.2          2.0  Iris-virginica
# 148  149           6.2          3.4           5.4          2.3  Iris-virginica
# 149  150           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df.columns = df.columns.str.lstrip()
print(df)
# Out:
#       Id  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width         species
# 0      1           5.1          3.5           1.4          0.2     Iris-setosa
# 1      2           4.9          3.0           1.4          0.2     Iris-setosa
# 2      3           4.7          3.2           1.3          0.2     Iris-setosa
# 3      4           4.6          3.1           1.5          0.2     Iris-setosa
# 4      5           5.0          3.6           1.4          0.2     Iris-setosa
# ..   ...           ...          ...           ...          ...             ...
# 145  146           6.7          3.0           5.2          2.3  Iris-virginica
# 146  147           6.3          2.5           5.0          1.9  Iris-virginica
# 147  148           6.5          3.0           5.2          2.0  Iris-virginica
# 148  149           6.2          3.4           5.4          2.3  Iris-virginica
# 149  150           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
plt.hist(df['species'])
plt.show()

# %%
#Displaying the shape of the dataset.
df.shape
# Out:
# (150, 6)

# %%
#Displaying a sample of 10 records
df.head(10)
# Out:
#    Id  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width      species
# 0   1           5.1          3.5           1.4          0.2  Iris-setosa
# 1   2           4.9          3.0           1.4          0.2  Iris-setosa
# 2   3           4.7          3.2           1.3          0.2  Iris-setosa
# 3   4           4.6          3.1           1.5          0.2  Iris-setosa
# 4   5           5.0          3.6           1.4          0.2  Iris-setosa
# 5   6           5.4          3.9           1.7          0.4  Iris-setosa
# 6   7           4.6          3.4           1.4          0.3  Iris-setosa
# 7   8           5.0          3.4           1.5          0.2  Iris-setosa
# 8   9           4.4          2.9           1.4          0.2  Iris-setosa
# 9  10           4.9          3.1           1.5          0.1  Iris-setosa

# %%
#Display the records from 10th row to 20th row
df.loc[10:20,:]
# Out:
#     Id  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width      species
# 10  11           5.4          3.7           1.5          0.2  Iris-setosa
# 11  12           4.8          3.4           1.6          0.2  Iris-setosa
# 12  13           4.8          3.0           1.4          0.1  Iris-setosa
# 13  14           4.3          3.0           1.1          0.1  Iris-setosa
# 14  15           5.8          4.0           1.2          0.2  Iris-setosa
# 15  16           5.7          4.4           1.5          0.4  Iris-setosa
# 16  17           5.1          3.5           1.4          0.3  Iris-setosa
# 17  18           5.4          3.9           1.3          0.4  Iris-setosa
# 18  19           5.7          3.8           1.7          0.3  Iris-setosa
# 19  20           5.1          3.8           1.5          0.3  Iris-setosa
# 20  21           5.4          3.4           1.7          0.2  Iris-setosa

# %%
#Drop the duplicate records
df.drop_duplicates()
# Out:
#       Id  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width         species
# 0      1           5.1          3.5           1.4          0.2     Iris-setosa
# 1      2           4.9          3.0           1.4          0.2     Iris-setosa
# 2      3           4.7          3.2           1.3          0.2     Iris-setosa
# 3      4           4.6          3.1           1.5          0.2     Iris-setosa
# 4      5           5.0          3.6           1.4          0.2     Iris-setosa
# ..   ...           ...          ...           ...          ...             ...
# 145  146           6.7          3.0           5.2          2.3  Iris-virginica
# 146  147           6.3          2.5           5.0          1.9  Iris-virginica
# 147  148           6.5          3.0           5.2          2.0  Iris-virginica
# 148  149           6.2          3.4           5.4          2.3  Iris-virginica
# 149  150           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
#Count the number of unique species
len(df['species'].unique())
# Out:
# 3

# %%
len(df['species'].value_counts().index)
# Out:
# 3

# %%
# Sort the data based on sepal length
df.sort_values('Sepal.Length')
# Out:
#       Id  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width         species
# 13    14           4.3          3.0           1.1          0.1     Iris-setosa
# 42    43           4.4          3.2           1.3          0.2     Iris-setosa
# 38    39           4.4          3.0           1.3          0.2     Iris-setosa
# 8      9           4.4          2.9           1.4          0.2     Iris-setosa
# 41    42           4.5          2.3           1.3          0.3     Iris-setosa
# ..   ...           ...          ...           ...          ...             ...
# 122  123           7.7          2.8           6.7          2.0  Iris-virginica
# 118  119           7.7          2.6           6.9          2.3  Iris-virginica
# 117  118           7.7          3.8           6.7          2.2  Iris-virginica
# 135  136           7.7          3.0           6.1          2.3  Iris-virginica
# 131  132           7.9          3.8           6.4          2.0  Iris-virginica
#
# [150 rows x 6 columns]

# %%
#Calculate the sum, mean and mode of the petal length
df['Petal.Length'].sum()
# Out:
# 563.8

# %%
df['Petal.Length'].mean()
# Out:
# 3.758666666666666

# %%
df['Petal.Length'].mode()
# Out:
# 0    1.5
# Name: Petal.Length, dtype: float64

# %%
#Extracting minimum and maximum value from sepal width
min_sw = df['Sepal.Width'].min()
max_sw = df['Sepal.Width'].max()
print('Min:',min_sw)
print('Max:',max_sw)
# Out:
# Min: 2.0
# Max: 4.4

# %%
#Fetch the records with petal length > 4cm
df.loc[df['Petal.Length'] > 4,:]
# Out:
#       Id  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 50    51           7.0          3.2           4.7          1.4
# 51    52           6.4          3.2           4.5          1.5
# 52    53           6.9          3.1           4.9          1.5
# 54    55           6.5          2.8           4.6          1.5
# 55    56           5.7          2.8           4.5          1.3
# ..   ...           ...          ...           ...          ...
# 145  146           6.7          3.0           5.2          2.3
# 146  147           6.3          2.5           5.0          1.9
# 147  148           6.5          3.0           5.2          2.0
# 148  149           6.2          3.4           5.4          2.3
# 149  150           5.9          3.0           5.1          1.8
#
#              species
# 50   Iris-versicolor
# 51   Iris-versicolor
# 52   Iris-versicolor
# 54   Iris-versicolor
# 55   Iris-versicolor
# ..               ...
# 145   Iris-virginica
# 146   Iris-virginica
# ...

# %%
#Split the data based on species type and find the mean sepal length
g = df.groupby('species')

g.head()  # i am displaying few from each group of species

#we can retrieve all of them by
#for x in g:
##   print(x)
# Out:
#       Id  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0      1           5.1          3.5           1.4          0.2
# 1      2           4.9          3.0           1.4          0.2
# 2      3           4.7          3.2           1.3          0.2
# 3      4           4.6          3.1           1.5          0.2
# 4      5           5.0          3.6           1.4          0.2
# 50    51           7.0          3.2           4.7          1.4
# 51    52           6.4          3.2           4.5          1.5
# 52    53           6.9          3.1           4.9          1.5
# 53    54           5.5          2.3           4.0          1.3
# 54    55           6.5          2.8           4.6          1.5
# 100  101           6.3          3.3           6.0          2.5
# 101  102           5.8          2.7           5.1          1.9
# 102  103           7.1          3.0           5.9          2.1
# 103  104           6.3          2.9           5.6          1.8
# ...

# %%
#Mean sepal length
gr_data = g.agg({'Sepal.Length' : 'mean'})
gr_data
# Out:
#                  Sepal.Length
# species
# Iris-setosa             5.006
# Iris-versicolor         5.936
# Iris-virginica          6.588

# %%
#Add new attribute 'total' that stores the sum of sepal width and petal width
df['total'] = df['Petal.Width'] + df['Sepal.Width']
df
# Out:
#       Id  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0      1           5.1          3.5           1.4          0.2
# 1      2           4.9          3.0           1.4          0.2
# 2      3           4.7          3.2           1.3          0.2
# 3      4           4.6          3.1           1.5          0.2
# 4      5           5.0          3.6           1.4          0.2
# ..   ...           ...          ...           ...          ...
# 145  146           6.7          3.0           5.2          2.3
# 146  147           6.3          2.5           5.0          1.9
# 147  148           6.5          3.0           5.2          2.0
# 148  149           6.2          3.4           5.4          2.3
# 149  150           5.9          3.0           5.1          1.8
#
#             species  total
# 0       Iris-setosa    3.7
# 1       Iris-setosa    3.2
# 2       Iris-setosa    3.4
# 3       Iris-setosa    3.3
# 4       Iris-setosa    3.8
# ..              ...    ...
# ...

# %%
#Set the values of the rows 10 to 19 of the column 'Petal.Length' to NaN
df.loc[10:20,'Petal.Length'] = np.nan
df.loc[10:20,'Petal.Length']
# Out:
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# Name: Petal.Length, dtype: float64

# %%
#Fill the NA values with its mean
mean_PLen = df['Petal.Length'].mean()  #3.9417266187050357
df['Petal.Length'] = df['Petal.Length'].fillna(round(df['Petal.Length'].mean(),2))
df.loc[10:20,'Petal.Length']
# Out:
# 10    3.94
# 11    3.94
# 12    3.94
# 13    3.94
# 14    3.94
# 15    3.94
# 16    3.94
# 17    3.94
# 18    3.94
# 19    3.94
# 20    3.94
# Name: Petal.Length, dtype: float64

# %%
plt.hist(df['species'])
plt.show()
